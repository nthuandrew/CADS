# %%
import torch
import pandas as pd
import numpy as np
augment_df1 = pd.read_excel(f'data/final/article/A1_be_augment_1_0530_fold_1.xlsx').fillna("")
augment_df2 = pd.read_excel(f'data/final/article/A1_be_augment_0_0530_fold_1.xlsx').fillna("")
origin_df = pd.read_excel(f'data/final/article/A1_train_moveAug_0530_fold_1.xlsx').fillna("")
# origin_df = pd.read_excel('data/article/train_A1_A2_1113_v2.xlsx').fillna("")
augment_df = pd.concat([augment_df1, augment_df2],axis=0, ignore_index=True)

# statistic of origin_df

print(origin_df['Crisis_Level'].value_counts())
# Out:
# 0    437
# 1    266
# 2    160
# 3     76
# Name: Crisis_Level, dtype: int64

# %%
print(augment_df['自殺與憂鬱'][2].split())
augment = augment_df['自殺與憂鬱'].dropna()
total = 0
all_negative_sentence = []
for idx,para in enumerate(augment):
    # print(para.split('_')[1:])
    # if idx != 1:
    total += len(para.split(' '))
    all_negative_sentence += para.split(' ')
print(total)
print(all_negative_sentence)
# remove all empty string in all_negative_sentence
all_negative_sentence = list(filter(None, all_negative_sentence))
print(len(all_negative_sentence))
print(all_negative_sentence)
sentence_len = len(all_negative_sentence)
# Out:
# ['不知道從什麼時候開始，發現自己的笑容開始不如以前', '看到現在的笑都覺得好虛偽', '好像找不回以前的笑容', '甚至不想看到自己的臉', '我一直以為只是我太負面', '國中的時候常常被班上男同學言語霸凌', '好像比以前更容易焦慮', '自認為自己的個性有點小心謹慎', '雖然我也不覺得會有人因此來關心我就是', '每次講到這樣子的事情，都會先懷疑是不是自己太玻璃', '我一直覺得自己好像病了', '但又怕會不會只是自己太玻璃', '不太清楚自己是否有憂鬱症', '可是有時候卻又不在乎是否活著', '直到有一次做夢夢到跟家人一起自殺', '跟家人講後，他們認為我壓力太大', '我知道自己一直壓力都很大，只是把他當成求學必經的過程罷了']
# 574
# ['', '8:16', '我跟我的自卑感相處', '很痛苦', '覺得很孤單', '', '', '不知道從什麼時候開始，發現自己的笑容開始不如以前', '看到現在的笑都覺得好虛偽', '好像找不回以前的笑容', '甚至不想看到自己的臉', '我一直以為只是我太負面', '國中的時候常常被班上男同學言語霸凌', '好像比以前更容易焦慮', '自認為自己的個性有點小心謹慎', '雖然我也不覺得會有人因此來關心我就是', '每次講到這樣子的事情，都會先懷疑是不是自己太玻璃', '我一直覺得自己好像病了', '但又怕會不會只是自己太玻璃', '不太清楚自己是否有憂鬱症', '可是有時候卻又不在乎是否活著', '直到有一次做夢夢到跟家人一起自殺', '跟家人講後，他們認為我壓力太大', '我知道自己一直壓力都很大，只是把他當成求學必經的過程罷了', '', '是眼神帶有殺氣與不屑、質疑、惱怒、不爽', '', '剛剛跟家人說，但卻被完全否定', '更加低落很想消失', '', '都會害怕他們是不是想利用我', '或者其實很討厭我', '最後又會自我厭惡', '對自己失望', '', '', '覺得自己很廢', '', '怎麼辦，感覺是自己把大家都推在外面', '好想消失', '好想不見', '消失了應該也沒差', '我沒有任何價值', '對大家來說', '事實上是不是我都無所謂，只是我剛好在那裡而已', '我對大家來說就是個可有可無的存在', '我沒有任何價值。', '我很自私，我付出的同時雖然一部分是心甘情願', '討厭社交，討厭跟人講話', '我好討厭', '我好奇怪', '我好機掰', '我好累', '好累好累', '', '為什麼活著總是這麼困難', '這麼折磨....', '', '', '', '同學說什麼我都聽不懂', '看病做檢查說沒事然後指責我說謊說我故意考爛', '自己的感覺都被否定到自己都質疑自己了', '因為我太糞', '還只會怨天尤人', '誰叫我長這樣個性這樣沒人用沒有自主能力', '', '活在一個這麼惡意滿點的世界真的很痛苦，為什麼今天不用去看醫生啊', '開那種吃下去會直接失去睡死的藥給我吃，可能就不用這麼痛苦了。', '更可悲的是鼓起勇氣說出來還會被一群男生、女生、同性戀嘲笑說是自己的問題', '自己長太醜吧~哈哈哈哈小雞雞~', '每天和這種惡意共感的我最後就是真的快生病了，因為很噁心', '', '我被我媽還有我爸還有奶奶罵怎麼會有這種女人冷血成這樣。', '每次吵架都在哭，但卻什麼都不敢做，只會罵我不孝一直激她離婚', '每次吵架都是我害的', '用講越激動就變成吵架，加上我們家奶奶很會倚老賣老說我亂講話', '我不聽我媽還對我罵我不孝她就是因為我才要受苦', '', '', '我活了這麼久', '你是我女兒我會不知道你是不是同性戀嗎？', '從小這麼愛漂亮怎麼會是同性戀！你根本不是完全的同性戀', '現在的教育就是這麼失敗', '原本不是同性戀的都以為自己是', '媽媽也說我這樣讓他覺得很丟臉', '千萬別讓別人知道這件事不然我女兒就毀了', '想不到活著到底為了什麼', '漫無目的的活著', '有時候會想要不要死了讓他們後悔自己的自以為是', '但這樣好像太自私了，我也不敢', '每天這樣偽裝自己', '', '卻被之前的一個好兄弟罵得很難聽', '是憂鬱症嗎', '還是就只是自己多想太多', '', '爛學校還有人要請妳當家教…為什麼我要一直被你們扁低', '那既然如此何必一開始就掐死我不是比較快速', '你/妳不信任我們，一發作就翻我們的書包和手機', '', '已經失去所有的熱情好一陣了', '既不重要', '不精采', '也無法讓我假裝快樂太久', '很快地就燒完', '然後突然間把我丟回極端無聊', '但是覺得自己不值得被注意到', '有什麼好被可憐的？', '像這樣責備自己', '果然是太自私了吧', '', '', '我一直以為，我是沒有安全感的，所以，我不怎麼把心全部給別人', '可是，直到昨天晚上才知道，不是我不信任別人，而是我不值得被信任', '對不起，我欺騙了你們，以為我是好人吧，不是的', '我是婊子、廢渣、不值得放心的人。', '我會自己離開的，不想再隨意的傷害人了，再見了', '一直覺得我不是黑暗人的人生。', '我，是騙子，是瘋子，是什麼都做不好的人，不要對我有期待', '我一定會讓你失望，不要對我有信賴，我一定會讓你生氣。', '我到昨天才知道，我活得那麼虛假，還憑什麼去要求人家', '還憑什麼去拿禮物，我不值得...不值得', '', '', '升上五專後…我（魔羯座）發現我比以前還要兩極化…', '一個是內在很冷靜…很容易有自私的想法（但一下子就消失了…）、很容易對別人的話在意、負面想法很多', '問題只會更嚴重…但她們卻說我脾氣不好…（她們有時很白目踩到我的底線…跟她們講…她們都笑笑帶過…完全不會反省…）', '我根本不知道…我活在這個世界上到底有什麼意義？為什麼我對人那麼好…她們都覺得這是應該的…', '', '', '現在的我有點處於悲傷憂鬱狀態', '感覺所有人的目光都在看著我', '感覺所有人都在背後議論我', '嘲笑我', '', '都認為我很沒用', '扯後腿', '而我又不敢表達我自己', '我不敢放得開', '我覺得我什麼事情都做不好', '我其實小學時曾經被霸凌過', '只因為我是個微胖女', '我很不快樂', '我討厭我自己', '討厭我會害怕跟男生相處', '討厭在團體中只能當被動者', '', '常常會有把妳頭砍下來、殺死妳、腿打斷等字眼', '', '覺得自己沒用', '', '這陣子的自我感受很差', '沒有自我認同感', '自己到底有什麼用', '好像真的很沒用', '覺得自己很沒用很廢很可悲', '他說這樣的我感覺真有距離', '今天他好像也心情不好我好想也回饋他對我做的', '', '都是負能量居多呢？', '生活上其實根本沒什麼快樂的事，是吧。', '怎麼，我真的做人很失敗嗎？', '還是，我就只是個工具人？', '', '每天承受這些精神壓力，', '', '抱歉現在心情有點焦慮和複雜', '以前被排擠的陰影就會浮現出來', '有種第六感是在說我，但是其他人都說我想太多', '', '但說起來好笑，我其實也不會說話', '在我給你建議的時候，你覺得我在瞧不起你', '在我安靜陪伴你的時候，你覺得我已經不愛你', '我覺得我也要病了', '', '又或許純粹只是我的包容力不夠而已', '或是，我跟著生病了而已', '', '，我就會很玻璃心', '，在想為什麼你要這樣對我', '，我跟你有仇嗎', '，擔心是不是任何人都在講我的壞話', '！', '我覺得我跟身邊的人', '不管是誰', '我都處不來', '', '本身最近可能有精神疾病', '看看是自律神經失調還是焦慮症或憂鬱症之類的', '為什麼要活著', '', '常常一天結束，看看自己中的自己：好陌生喔', '生病了嗎？為什麼對每個人都只感到距離感', '看著四周的朋友越來越難懂', '好諷刺', '他們討厭的人彷彿是他們自己', '是我變了嗎？看著對這群「朋友」的諷刺行為只會感到害怕', '', '一個人孤立無援的感覺', '我才知道自己這麼怕孤單', '這幾天的想法變得消極', '也想過要放棄', '感覺就像是放棄自己的人生', '我怎麼會變這麼消極', '對這樣沒用的自己感到失望', '隨便一點小事就壓垮我', '從來沒有這樣討厭自己', '其實我根本就是個廢物', '', '心裡的感覺好難受啊', '', '', '', '連我也憂鬱症了', '', '', '', '很大的精神壓力', '這個真的造成我很大的心裡壓力', '（白話文：我的快樂就是建築在你的痛苦上啦）', '', '', '家裡的氣氛已經糟到沒人想待下去了', '我跟我哥哥的心理狀態也變得不太穩定', '', '我不值得任何人同情', '也沒資格抱怨', '又被貼上罪人標籤', '被笑，活該', '不值得安慰，我今後不敢面對別人的表情了', '他們會用情緒殺了我', '活著也是空殼', '被人給唾棄，被酸民嘲諷貶低', '對不起，我是個....', '', '但換來的卻是，被忽略被開玩笑不在意的心態', '請問', '有把我放在眼裡嗎', '', '但我才剛畢業啊，壓力好大QAQ', '', '', '', '也會覺得自己很糟糕為什麼要這麼憂鬱', '但我害怕自己有輕度的憂鬱症', '變得沒有像以前開朗', '很多時候都不想跟人家說', '想一個人獨處', '', '我曾經告訴他：我覺得我好像怪物好像神經病', '但是我好想結束', '', '動不動就罵我難聽的字眼，也不覺得自己哪裡有問題', '', '面對同事們職場霸凌', '', '', '我認為的朋友說覺得我很可憐，真心的朋友很少', '對朋友。', '我自認我沒有哪裡對不起他們', '', '從那時候開始我的身心狀況越來越差。', '他就會說我們都不關心他，情緒勒索我們', '就會莫名的心情低落或煩躁，還有罪惡感。', '我討厭這樣的自己⋯⋯⋯⋯⋯⋯⋯⋯⋯', '上網做了幾個不同的憂鬱量表，都有憂鬱傾向⋯⋯⋯⋯⋯⋯', '', '', '還是有一部分的自己持續抑鬱', '但更多的時候是對自己感到茫然', '有時候會覺得自己太過於矯情', '好像在無病呻吟', '', '讓我相信自己不是那麼糟糕', '連自己都不喜歡的自己', '', '從小到大 ...
# 368
# ['8:16', '我跟我的自卑感相處', '很痛苦', '覺得很孤單', '不知道從什麼時候開始，發現自己的笑容開始不如以前', '看到現在的笑都覺得好虛偽', '好像找不回以前的笑容', '甚至不想看到自己的臉', '我一直以為只是我太負面', '國中的時候常常被班上男同學言語霸凌', '好像比以前更容易焦慮', '自認為自己的個性有點小心謹慎', '雖然我也不覺得會有人因此來關心我就是', '每次講到這樣子的事情，都會先懷疑是不是自己太玻璃', '我一直覺得自己好像病了', '但又怕會不會只是自己太玻璃', '不太清楚自己是否有憂鬱症', '可是有時候卻又不在乎是否活著', '直到有一次做夢夢到跟家人一起自殺', '跟家人講後，他們認為我壓力太大', '我知道自己一直壓力都很大，只是把他當成求學必經的過程罷了', '是眼神帶有殺氣與不屑、質疑、惱怒、不爽', '剛剛跟家人說，但卻被完全否定', '更加低落很想消失', '都會害怕他們是不是想利用我', '或者其實很討厭我', '最後又會自我厭惡', '對自己失望', '覺得自己很廢', '怎麼辦，感覺是自己把大家都推在外面', '好想消失', '好想不見', '消失了應該也沒差', '我沒有任何價值', '對大家來說', '事實上是不是我都無所謂，只是我剛好在那裡而已', '我對大家來說就是個可有可無的存在', '我沒有任何價值。', '我很自私，我付出的同時雖然一部分是心甘情願', '討厭社交，討厭跟人講話', '我好討厭', '我好奇怪', '我好機掰', '我好累', '好累好累', '為什麼活著總是這麼困難', '這麼折磨....', '同學說什麼我都聽不懂', '看病做檢查說沒事然後指責我說謊說我故意考爛', '自己的感覺都被否定到自己都質疑自己了', '因為我太糞', '還只會怨天尤人', '誰叫我長這樣個性這樣沒人用沒有自主能力', '活在一個這麼惡意滿點的世界真的很痛苦，為什麼今天不用去看醫生啊', '開那種吃下去會直接失去睡死的藥給我吃，可能就不用這麼痛苦了。', '更可悲的是鼓起勇氣說出來還會被一群男生、女生、同性戀嘲笑說是自己的問題', '自己長太醜吧~哈哈哈哈小雞雞~', '每天和這種惡意共感的我最後就是真的快生病了，因為很噁心', '我被我媽還有我爸還有奶奶罵怎麼會有這種女人冷血成這樣。', '每次吵架都在哭，但卻什麼都不敢做，只會罵我不孝一直激她離婚', '每次吵架都是我害的', '用講越激動就變成吵架，加上我們家奶奶很會倚老賣老說我亂講話', '我不聽我媽還對我罵我不孝她就是因為我才要受苦', '我活了這麼久', '你是我女兒我會不知道你是不是同性戀嗎？', '從小這麼愛漂亮怎麼會是同性戀！你根本不是完全的同性戀', '現在的教育就是這麼失敗', '原本不是同性戀的都以為自己是', '媽媽也說我這樣讓他覺得很丟臉', '千萬別讓別人知道這件事不然我女兒就毀了', '想不到活著到底為了什麼', '漫無目的的活著', '有時候會想要不要死了讓他們後悔自己的自以為是', '但這樣好像太自私了，我也不敢', '每天這樣偽裝自己', '卻被之前的一個好兄弟罵得很難聽', '是憂鬱症嗎', '還是就只是自己多想太多', '爛學校還有人要請妳當家教…為什麼我要一直被你們扁低', '那既然如此何必一開始就掐死我不是比較快速', '你/妳不信任我們，一發作就翻我們的書包和手機', '已經失去所有的熱情好一陣了', '既不重要', '不精采', '也無法讓我假裝快樂太久', '很快地就燒完', '然後突然間把我丟回極端無聊', '但是覺得自己不值得被注意到', '有什麼好被可憐的？', '像這樣責備自己', '果然是太自私了吧', '我一直以為，我是沒有安全感的，所以，我不怎麼把心全部給別人', '可是，直到昨天晚上才知道，不是我不信任別人，而是我不值得被信任', '對不起，我欺騙了你們，以為我是好人吧，不是的', '我是婊子、廢渣、不值得放心的人。', '我會自己離開的，不想再隨意的傷害人了，再見了', '一直覺得我不是黑暗人的人生。', '我，是騙子，是瘋子，是什麼都做不好的人，不要對我有期待', '我一定會讓你失望，不要對我有信賴，我一定會讓你生氣。', '我到昨天才知道，我活得那麼虛假，還憑什麼去要求人家', '還憑什麼去拿禮物，我不值得...不值得', '升上五專後…我（魔羯座）發現我比以前還要兩極化…', '一個是內在很冷靜…很容易有自私的想法（但一下子就消失了…）、很容易對別人的話在意、負面想法很多', '問題只會更嚴重…但她們卻說我脾氣不好…（她們有時很白目踩到我的底線…跟她們講…她們都笑笑帶過…完全不會反省…）', '我根本不知道…我活在這個世界上到底有什麼意義？為什麼我對人那麼好…她們都覺得這是應該的…', '現在的我有點處於悲傷憂鬱狀態', '感覺所有人的目光都在看著我', '感覺所有人都在背後議論我', '嘲笑我', '都認為我很沒用', '扯後腿', '而我又不敢表達我自己', '我不敢放得開', '我覺得我什麼事情都做不好', '我其實小學時曾經被霸凌過', '只因為我是個微胖女', '我很不快樂', '我討厭我自己', '討厭我會害怕跟男生相處', '討厭在團體中只能當被動者', '常常會有把妳頭砍下來、殺死妳、腿打斷等字眼', '覺得自己沒用', '這陣子的自我感受很差', '沒有自我認同感', '自己到底有什麼用', '好像真的很沒用', '覺得自己很沒用很廢很可悲', '他說這樣的我感覺真有距離', '今天他好像也心情不好我好想也回饋他對我做的', '都是負能量居多呢？', '生活上其實根本沒什麼快樂的事，是吧。', '怎麼，我真的做人很失敗嗎？', '還是，我就只是個工具人？', '每天承受這些精神壓力，', '抱歉現在心情有點焦慮和複雜', '以前被排擠的陰影就會浮現出來', '有種第六感是在說我，但是其他人都說我想太多', '但說起來好笑，我其實也不會說話', '在我給你建議的時候，你覺得我在瞧不起你', '在我安靜陪伴你的時候，你覺得我已經不愛你', '我覺得我也要病了', '又或許純粹只是我的包容力不夠而已', '或是，我跟著生病了而已', '，我就會很玻璃心', '，在想為什麼你要這樣對我', '，我跟你有仇嗎', '，擔心是不是任何人都在講我的壞話', '！', '我覺得我跟身邊的人', '不管是誰', '我都處不來', '本身最近可能有精神疾病', '看看是自律神經失調還是焦慮症或憂鬱症之類的', '為什麼要活著', '常常一天結束，看看自己中的自己：好陌生喔', '生病了嗎？為什麼對每個人都只感到距離感', '看著四周的朋友越來越難懂', '好諷刺', '他們討厭的人彷彿是他們自己', '是我變了嗎？看著對這群「朋友」的諷刺行為只會感到害怕', '一個人孤立無援的感覺', '我才知道自己這麼怕孤單', '這幾天的想法變得消極', '也想過要放棄', '感覺就像是放棄自己的人生', '我怎麼會變這麼消極', '對這樣沒用的自己感到失望', '隨便一點小事就壓垮我', '從來沒有這樣討厭自己', '其實我根本就是個廢物', '心裡的感覺好難受啊', '連我也憂鬱症了', '很大的精神壓力', '這個真的造成我很大的心裡壓力', '（白話文：我的快樂就是建築在你的痛苦上啦）', '家裡的氣氛已經糟到沒人想待下去了', '我跟我哥哥的心理狀態也變得不太穩定', '我不值得任何人同情', '也沒資格抱怨', '又被貼上罪人標籤', '被笑，活該', '不值得安慰，我今後不敢面對別人的表情了', '他們會用情緒殺了我', '活著也是空殼', '被人給唾棄，被酸民嘲諷貶低', '對不起，我是個....', '但換來的卻是，被忽略被開玩笑不在意的心態', '請問', '有把我放在眼裡嗎', '但我才剛畢業啊，壓力好大QAQ', '也會覺得自己很糟糕為什麼要這麼憂鬱', '但我害怕自己有輕度的憂鬱症', '變得沒有像以前開朗', '很多時候都不想跟人家說', '想一個人獨處', '我曾經告訴他：我覺得我好像怪物好像神經病', '但是我好想結束', '動不動就罵我難聽的字眼，也不覺得自己哪裡有問題', '面對同事們職場霸凌', '我認為的朋友說覺得我很可憐，真心的朋友很少', '對朋友。', '我自認我沒有哪裡對不起他們', '從那時候開始我的身心狀況越來越差。', '他就會說我們都不關心他，情緒勒索我們', '就會莫名的心情低落或煩躁，還有罪惡感。', '我討厭這樣的自己⋯⋯⋯⋯⋯⋯⋯⋯⋯', '上網做了幾個不同的憂鬱量表，都有憂鬱傾向⋯⋯⋯⋯⋯⋯', '還是有一部分的自己持續抑鬱', '但更多的時候是對自己感到茫然', '有時候會覺得自己太過於矯情', '好像在無病呻吟', '讓我相信自己不是那麼糟糕', '連自己都不喜歡的自己', '從小到大我有時候覺得自己很悲觀', '常常很自卑，很玻璃心，亂想', '開始變得很負面、沒自信、在意他人眼光', '也不喜歡在人很多的地方', '讓朋友同學尷尬、讓家人擔心的我', '讓自己總是辛苦到不行的我', '存在的意義是什麼？我找不到', '總是想消失、想把自己取消、想把自己丟掉', '好不容易才喬好了，而我姐回頭罵我我是賤人我會不得好死。', '我自責愧疚到每天晚上都對鏡子自言自語你去死你去死。', '我不想休學，但我的理智告訴我，我真的撐不下去了。', '我已經破碎到連自己都撐不起來。', '或許會有人 ...

# %%
level_3_df = origin_df[origin_df['Crisis_Level'] == 3]
level_2_df = origin_df[origin_df['Crisis_Level'] == 2]
level_3_len = len(level_3_df)
level_2_len = len(level_2_df)
print(level_3_len)
print(level_2_len)
# Out:
# 76
# 160

# %%
# duplicate level_3_df from len = level_3_len to len = 100
augment_amount_of_level_2 = 150
level_3_df = pd.concat([level_3_df]*int(sentence_len/level_3_len), ignore_index=True)
# select the first 84+178 sentence
level_3_df = level_3_df.iloc[:sentence_len-augment_amount_of_level_2]
print(len(level_3_df))
# Out:
# 218

# %%
level_2_df = pd.concat([level_2_df]*int(sentence_len/level_3_len), ignore_index=True)
# select the first 84+178 sentence
level_2_df = level_2_df.iloc[:augment_amount_of_level_2]
print(len(level_2_df))
# Out:
# 150

# %%
# randomly choose a sentence from all_negative_sentence and replace with a sentence in level_3_df
import random
seed = 1
random.seed(seed)

for idx, row in level_3_df.iterrows():
    para = row['自殺與憂鬱'].split(' ')
    random_idx_1 = np.random.randint(0, len(para))  
    random_idx_2 = np.random.randint(0, len(all_negative_sentence))    
    para[random_idx_1] = all_negative_sentence[random_idx_2]
    all_negative_sentence.pop(random_idx_2)
    row['自殺與憂鬱'] = ' '.join(para)
    level_3_df.iloc[idx] = row
print(len(all_negative_sentence))
print(len(level_3_df))
# Out:
# 150
# 218

# %%
for idx, row in level_2_df.iterrows():
    para = row['自殺與憂鬱'].split(' ')
    random_idx_1 = np.random.randint(0, len(para))  
    random_idx_2 = np.random.randint(0, len(all_negative_sentence))    
    para[random_idx_1] = all_negative_sentence[random_idx_2]
    all_negative_sentence.pop(random_idx_2)
    row['自殺與憂鬱'] = ' '.join(para)
    level_2_df.iloc[idx] = row
print(len(all_negative_sentence))
print(len(level_2_df))
# Out:
# 0
# 150

# %%
# for idx, row in origin_df.iterrows():
# augment_df_list.append(origin_df)
# print(len(augment_df_list))
augmented_df = pd.concat([origin_df, level_3_df, level_2_df],axis=0, ignore_index=True)
print(augmented_df.columns)
statssss = [0]*4
for index, row in augmented_df.iterrows():
    statssss[row['Crisis_Level']] += 1
print(statssss)
# Out:
# Index(['無標註', '自殺與憂鬱', '無助或無望', '正向文字', '其他負向文字', '生理反應或醫療狀況', '自殺行為', '其他類型',
#        'label', 'Crisis_Level', 'TextID'],
#       dtype='object')
# [437, 266, 310, 294]

# %%
# balance augmented_df by crisis level, constrain the amount of each level under 600 
maxima = 500
augmented_df_v2 = augmented_df.groupby('Crisis_Level').head(maxima).reset_index(drop=True)
# random shuffle augmented_df_v2
# augmented_df_v2 = augmented_df_v2.sample(frac=1).reset_index(drop=True)
print(augmented_df_v2['Crisis_Level'].value_counts())
# Out:
# 0    437
# 2    310
# 3    294
# 1    266
# Name: Crisis_Level, dtype: int64

# %%
# shuffle the augmented_df without index and set the random_state
augmented_df_v2 = augmented_df_v2.sample(frac=1, random_state=seed).reset_index(drop=True)
# augmented_df.to_excel('data/article/train_augmented_1_v4.xlsx')
augmented_df_v2.to_excel(f'data/article/final/A1_train_augmented_0530_fold_1.xlsx.xlsx')

# %%
# convert to .py file
# !jupyter nbconvert --to script article_augmentation_0530.ipynb
# Out:
# [NbConvertApp] Converting notebook article_augmentation_0530.ipynb to script
# [NbConvertApp] Writing 4110 bytes to article_augmentation_0530.py
