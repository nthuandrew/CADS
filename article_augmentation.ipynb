# %%
import torch
import pandas as pd
import numpy as np
augment_df1 = pd.read_excel('data/article/augmentation_article_1_1108.xlsx').fillna("")
augment_df2 = pd.read_excel('data/article/augmentation_article_0_1108.xlsx').fillna("")
# origin_df = pd.read_excel('data/article/train_article_1108.xlsx').fillna("")
origin_df = pd.read_excel('data/article/train_A1_A2_1113_v2.xlsx').fillna("")
augment_df = pd.concat([augment_df1, augment_df2],axis=0, ignore_index=True)

# statistic of origin_df

print(origin_df['Crisis_Level'].value_counts())
# Out:
# 0    1229
# 1     623
# 2     287
# 3     133
# Name: Crisis_Level, dtype: int64

# %%
print(augment_df['自殺與憂鬱'][2].split())
augment = augment_df['自殺與憂鬱'].dropna()
total = 0
all_negative_sentence = []
for idx,para in enumerate(augment):
    # print(para.split('_')[1:])
    # if idx != 1:
    total += len(para.split(' '))
    all_negative_sentence += para.split(' ')
print(total)
print(all_negative_sentence)
# remove all empty string in all_negative_sentence
all_negative_sentence = list(filter(None, all_negative_sentence))
print(len(all_negative_sentence))
print(all_negative_sentence)
sentence_len = len(all_negative_sentence)
# Out:
# []
# 602
# ['', '在餐桌上被自己父母羞辱真的很可悲', '但在我失意的時候你們只會嘲笑我', '給我一個沒有歸屬感的家庭', '', '我知道可能是我太小孩子氣，我想控制我自己不要亂想', '', '', '還不被別人理解', '不被接受', '', '為什麼活著總是這麼困難', '這麼折磨....', '', '我不知道該怎麼面對我心中的黑暗面', '幻想自己的家人意外的死去', '以前甚至莫名其妙會有想自殺的衝動', '等等的', '我不敢面對生命的逝去', '拜託不要在下面說我只是想太多...拜託不要', '我已經為這件事痛苦一陣子了', '', '我被我媽還有我爸還有奶奶罵怎麼會有這種女人冷血成這樣。', '每次吵架都在哭，但卻什麼都不敢做，只會罵我不孝一直激她離婚', '每次吵架都是我害的', '用講越激動就變成吵架，加上我們家奶奶很會倚老賣老說我亂講話', '我不聽我媽還對我罵我不孝她就是因為我才要受苦', '', '我桌上每次我上學看到的就是一堆垃圾', '同學傳了一張紙條簽名聯合排擠我', '班導也直接把大家集合寫為什麼討厭我', '我不敢再交朋友了把自己關起來', '結果又被排擠', '因為我一直不知道自己到底是做錯了什麼', '', '有一點憂鬱也不好意思跟身邊朋友談論', '', '可能在你們眼裡我的不快樂就是那麼的虛渺，全都是自找的吧？', '', '', '結果哥哥的一群朋友跑來跟我哥抱怨我的臉很臭不好看', '就剛好他們看到我坐回位子的時候我的臉都不笑臉很臭', '', '我知道我很白目沒錯', '留言想鞭我就鞭', '不過我這樣被情緒勒索', '只有留下恐懼', '一定要逼到我認錯', '完全不聽我的想法跟感受', '', '爛學校還有人要請妳當家教…為什麼我要一直被你們扁低', '那既然如此何必一開始就掐死我不是比較快速', '你/妳不信任我們，一發作就翻我們的書包和手機', '', '例如有時候只是稍微不舒服就會覺得自己是不是得了絕症', '情緒緊繃的時候更嚴重，常常覺得自己是不是要死了呢？', '看著自己過的如廢物般的生活，我當然很想拯救自己', '然後不斷的對自己失望:disappointed_face:', '也許吧我真的是個沒有人推著就不會動的廢物。', '', '你有時暴怒的喊：「我要你幹嘛啊！？」這話講的讓人心寒', '在你還在說這句話時，可能已經有人被逼的變神經病了吧…', '', '一片黑暗看不見四周、看不見自己，也聽不清周圍的聲音', '所有人的聲音都像在很遠很遠的地方傳來，旋即消失在黑暗裡', '只有無止盡的掉落', '那些日子，我很容易暴躁、很容易沉默，情緒在極端的兩邊', '我瘋狂的表現快樂但內心也是無力挽救的低潮，不斷的反覆', '我感受不到自己', '沒有原因的...心裡很疲憊空虛茫然的感覺', '我的腦袋心裡都在歇斯底里的尖叫，不過維持表面上的笑容', '但是沒有原因啊！我只是在很糟的狀態，不是因為發生什麼', '突然進入這種狀態，我該怎麼解釋？我沒辦法解釋', '但通常很快就結束，從來沒有著陣子的我糟糕', '我做了抑鬱症的量表，18/27分', '努力活得像自己，可是好像不夠，我還是很down', '，差一點成功但又失敗，就像要爬起來的人又滑倒，然後摔的更重', '我不是想死，只是覺得活著很累，很努力的想活著，還有很想做的事', '可是好累...', '', '在高中結果一出來後', '爸爸開始對我開始唾棄', '甚至不跟我說話', '也曾說我是個廢物', '沒路用', '相對的我', '只要發下成績就開始罵我的高中有多爛', '以後沒有好未來', '從國小的成績超級不理想', '甚至多次被老師厭棄', '而我永遠都被父母認為是那個造就錯誤的人', '導致他糜爛的罪魁禍首', 'ab大學也沒好到哪裡去啦', '就是個廢物', '', '', '好不容易才喬好了，而我姐回頭罵我我是賤人我會不得好死。', '我自責愧疚到每天晚上都對鏡子自言自語你去死你去死。', '我不想休學，但我的理智告訴我，我真的撐不下去了。', '我已經破碎到連自己都撐不起來。', '或許會有人因為這罵我我無情，但我真的累了', '我只希望對方能一槍打死我，把這個在他眼中的無情垃圾除掉算了', '我已經被現實壓垮了。', '是指有人「因為我姐的事」打電話罵我', '她在文中都是用寫字和打字去問別人，和罵我的´_>`', '', '所以導致我長大有很多壞習慣…', '', '我是一個極度害怕孤獨的人，因為孤獨時會讓我感到無比害怕', '會開始陷入悲傷的深淵，會開始覺得自己很糟糕很沒用', '甚至會想消失在這個世界上，而至今也沒能找到一個真心的好朋友', '但不知道從什麼時候開始，自己開始沒辦法那麼輕易地依賴別人', '也害怕自己成為他們的負擔，所以只能用層層外殼包裝', '只能對他們說自己一切都很好，不讓他們擔憂，因為這樣才是好孩子', '', '', '我不懂社交的眉眉角角，聽不懂別人的言外之意，也看不懂肢體語言', '很容易被當成白目又不合群的人。', '從小到大我就一直處於被霸凌或排擠取笑的環境', '所以導致我非常害怕人', '我常討好完別人轉身就聽到別人罵我假掰或做作', '背地裡把我當笑話對待，這些情形其實我都看在眼裡', '', '小時候，我的長相並不討喜，也曾遭到霸凌', '「悶騷」、「自閉」、「邊緣」、「暴牙妹」……', '最嚴重的是直接當眾羞辱我，甚至把我的書包丟出去。', '我想盡各種自殺的方法，卻沒有勇氣下手', '更讓我覺得荒謬可笑的是，連老師也拿我的長相開玩笑', '抱歉，你說的一點都不好笑。', '拜託，別再拿我開玩笑了！', '我只能活在你們製造的陰霾之中', '我必須因為過去的陰影，而放棄未來', '曾經讓我感受到絕望的人，卻沒有受到報應', '我的陰影還在，你們卻活的無比逍遙自在———我對不起我自己', '你應該活的比他們好。。。', '', '', '覺得自己快死了，', '但我完全感覺不到任何東西，我真的覺得自己難受的快死了', '', '也時常會自卑', '可是這個世界這個要崩潰了...', '', '開始傳出了我「會爆氣」、「玻璃心」、「嘴不起」的傳言。', '但是卻成為了他們的嘴中的爆氣哥。', '', '我就不會變得這麼自私', '', '', '我真的好壞好噁心', '', '然後又私底下把我罵的很難聽', '也常常用一堆莫名其妙的事來罵我', '上班被罵被白眼', '下班又要接受人家私底下的批評', '', '明明對方沒有那個意思卻會一直往那裡想', '明明對方是為了你好才會講話難聽', '但是我的整個世界好像都要崩塌了', '會想放棄自己堅持的事', '會想逃開', '自己是不是很糟糕', '自己是不是被全世界討厭', '是不是太自卑太沒安全感了', '覺得自己很爛所以才需要別人認可', '一直告訴自己要獨立一點卻又做不到', '', '也覺得自己很沒用', '', '好久以前被學校同學老師霸凌後', '不知道是身形太弱小還是以前的陰影害的', '真的會想回去報復他們然後拜拜', '', '然而這四年卻彷彿成為我媽的污點似的，她總說我在這四年變了', '我不懂，為什麼她詢問我的字句中，覺得我孤僻，有社交障礙？', '', '我在畢業前兩個月得了自律神經失調。', '他研究完我的病歷後告訴我：「我認為你太焦慮了', '去處理我的焦慮問題，我安排了學校的諮商。', '', '我開始在生活中感覺不到情緒。', '但我就是感覺不到真實的情緒，', '有時候照著鏡子都覺得自己看了討厭，', '曾經有朋友說過在一開始相處時我看起來很不真誠，', '不好親近、像是說著場面話、客套著。', '我不喜歡我自己，', '被自己的情緒反撲到甚至失去生存意識。', '察覺到自己的不對勁，', '巨大的背叛、孤立、父母的失和，', '害怕自己沒辦法處理、也沒有任何人可以穩穩的接住我。', '都是別人說：妳很辛苦，你應該很難過很無助吧？', '看見了一個破碎的自己，', '在一層一層自我保護下壞的亂七八糟的自己蹲在那裡，', '', '現在的我有點處於悲傷憂鬱狀態', '感覺所有人的目光都在看著我', '感覺所有人都在背後議論我', '嘲笑我', '', '都認為我很沒用', '扯後腿', '而我又不敢表達我自己', '我不敢放得開', '我覺得我什麼事情都做不好', '我其實小學時曾經被霸凌過', '只因為我是個微胖女', '我很不快樂', '我討厭我自己', '討厭我會害怕跟男生相處', '討厭在團體中只能當被動者', '', '', '', '回到公司之後，開始各種找人講我壞話', '我現在在公司', '根本成了眾矢之的…', '甚至每天都有人當著我的面碎念我，嘲笑我，行為針對我…', '對於自己的個性加上', '無法承受被公司眾多人的行為上霸凌傷害…', '跟同事鬧翻+被同事背叛…整個公司的人討厭我', '現在，我連一年都不想撐了，體會到真正的傷心絕望', '但是每天反覆的想', '我快得病了⋯⋯', '', '，我就會很玻璃心', '，在想為什麼你要這樣對我', '，我跟你有仇嗎', '，擔心是不是任何人都在講我的壞話', '！', '我覺得我跟身邊的人', '不管是誰', '我都處不來', '', '常常覺得活著怎麼這麼累', '陷入極度焦慮的時候', '', '我只想要自己勇敢一點，每當看到身邊的人想做就做、想說就說', '而我卻無法隨心所欲...導致最後什麼也沒做沒說。', '很 ...
# 400
# ['在餐桌上被自己父母羞辱真的很可悲', '但在我失意的時候你們只會嘲笑我', '給我一個沒有歸屬感的家庭', '我知道可能是我太小孩子氣，我想控制我自己不要亂想', '還不被別人理解', '不被接受', '為什麼活著總是這麼困難', '這麼折磨....', '我不知道該怎麼面對我心中的黑暗面', '幻想自己的家人意外的死去', '以前甚至莫名其妙會有想自殺的衝動', '等等的', '我不敢面對生命的逝去', '拜託不要在下面說我只是想太多...拜託不要', '我已經為這件事痛苦一陣子了', '我被我媽還有我爸還有奶奶罵怎麼會有這種女人冷血成這樣。', '每次吵架都在哭，但卻什麼都不敢做，只會罵我不孝一直激她離婚', '每次吵架都是我害的', '用講越激動就變成吵架，加上我們家奶奶很會倚老賣老說我亂講話', '我不聽我媽還對我罵我不孝她就是因為我才要受苦', '我桌上每次我上學看到的就是一堆垃圾', '同學傳了一張紙條簽名聯合排擠我', '班導也直接把大家集合寫為什麼討厭我', '我不敢再交朋友了把自己關起來', '結果又被排擠', '因為我一直不知道自己到底是做錯了什麼', '有一點憂鬱也不好意思跟身邊朋友談論', '可能在你們眼裡我的不快樂就是那麼的虛渺，全都是自找的吧？', '結果哥哥的一群朋友跑來跟我哥抱怨我的臉很臭不好看', '就剛好他們看到我坐回位子的時候我的臉都不笑臉很臭', '我知道我很白目沒錯', '留言想鞭我就鞭', '不過我這樣被情緒勒索', '只有留下恐懼', '一定要逼到我認錯', '完全不聽我的想法跟感受', '爛學校還有人要請妳當家教…為什麼我要一直被你們扁低', '那既然如此何必一開始就掐死我不是比較快速', '你/妳不信任我們，一發作就翻我們的書包和手機', '例如有時候只是稍微不舒服就會覺得自己是不是得了絕症', '情緒緊繃的時候更嚴重，常常覺得自己是不是要死了呢？', '看著自己過的如廢物般的生活，我當然很想拯救自己', '然後不斷的對自己失望:disappointed_face:', '也許吧我真的是個沒有人推著就不會動的廢物。', '你有時暴怒的喊：「我要你幹嘛啊！？」這話講的讓人心寒', '在你還在說這句話時，可能已經有人被逼的變神經病了吧…', '一片黑暗看不見四周、看不見自己，也聽不清周圍的聲音', '所有人的聲音都像在很遠很遠的地方傳來，旋即消失在黑暗裡', '只有無止盡的掉落', '那些日子，我很容易暴躁、很容易沉默，情緒在極端的兩邊', '我瘋狂的表現快樂但內心也是無力挽救的低潮，不斷的反覆', '我感受不到自己', '沒有原因的...心裡很疲憊空虛茫然的感覺', '我的腦袋心裡都在歇斯底里的尖叫，不過維持表面上的笑容', '但是沒有原因啊！我只是在很糟的狀態，不是因為發生什麼', '突然進入這種狀態，我該怎麼解釋？我沒辦法解釋', '但通常很快就結束，從來沒有著陣子的我糟糕', '我做了抑鬱症的量表，18/27分', '努力活得像自己，可是好像不夠，我還是很down', '，差一點成功但又失敗，就像要爬起來的人又滑倒，然後摔的更重', '我不是想死，只是覺得活著很累，很努力的想活著，還有很想做的事', '可是好累...', '在高中結果一出來後', '爸爸開始對我開始唾棄', '甚至不跟我說話', '也曾說我是個廢物', '沒路用', '相對的我', '只要發下成績就開始罵我的高中有多爛', '以後沒有好未來', '從國小的成績超級不理想', '甚至多次被老師厭棄', '而我永遠都被父母認為是那個造就錯誤的人', '導致他糜爛的罪魁禍首', 'ab大學也沒好到哪裡去啦', '就是個廢物', '好不容易才喬好了，而我姐回頭罵我我是賤人我會不得好死。', '我自責愧疚到每天晚上都對鏡子自言自語你去死你去死。', '我不想休學，但我的理智告訴我，我真的撐不下去了。', '我已經破碎到連自己都撐不起來。', '或許會有人因為這罵我我無情，但我真的累了', '我只希望對方能一槍打死我，把這個在他眼中的無情垃圾除掉算了', '我已經被現實壓垮了。', '是指有人「因為我姐的事」打電話罵我', '她在文中都是用寫字和打字去問別人，和罵我的´_>`', '所以導致我長大有很多壞習慣…', '我是一個極度害怕孤獨的人，因為孤獨時會讓我感到無比害怕', '會開始陷入悲傷的深淵，會開始覺得自己很糟糕很沒用', '甚至會想消失在這個世界上，而至今也沒能找到一個真心的好朋友', '但不知道從什麼時候開始，自己開始沒辦法那麼輕易地依賴別人', '也害怕自己成為他們的負擔，所以只能用層層外殼包裝', '只能對他們說自己一切都很好，不讓他們擔憂，因為這樣才是好孩子', '我不懂社交的眉眉角角，聽不懂別人的言外之意，也看不懂肢體語言', '很容易被當成白目又不合群的人。', '從小到大我就一直處於被霸凌或排擠取笑的環境', '所以導致我非常害怕人', '我常討好完別人轉身就聽到別人罵我假掰或做作', '背地裡把我當笑話對待，這些情形其實我都看在眼裡', '小時候，我的長相並不討喜，也曾遭到霸凌', '「悶騷」、「自閉」、「邊緣」、「暴牙妹」……', '最嚴重的是直接當眾羞辱我，甚至把我的書包丟出去。', '我想盡各種自殺的方法，卻沒有勇氣下手', '更讓我覺得荒謬可笑的是，連老師也拿我的長相開玩笑', '抱歉，你說的一點都不好笑。', '拜託，別再拿我開玩笑了！', '我只能活在你們製造的陰霾之中', '我必須因為過去的陰影，而放棄未來', '曾經讓我感受到絕望的人，卻沒有受到報應', '我的陰影還在，你們卻活的無比逍遙自在———我對不起我自己', '你應該活的比他們好。。。', '覺得自己快死了，', '但我完全感覺不到任何東西，我真的覺得自己難受的快死了', '也時常會自卑', '可是這個世界這個要崩潰了...', '開始傳出了我「會爆氣」、「玻璃心」、「嘴不起」的傳言。', '但是卻成為了他們的嘴中的爆氣哥。', '我就不會變得這麼自私', '我真的好壞好噁心', '然後又私底下把我罵的很難聽', '也常常用一堆莫名其妙的事來罵我', '上班被罵被白眼', '下班又要接受人家私底下的批評', '明明對方沒有那個意思卻會一直往那裡想', '明明對方是為了你好才會講話難聽', '但是我的整個世界好像都要崩塌了', '會想放棄自己堅持的事', '會想逃開', '自己是不是很糟糕', '自己是不是被全世界討厭', '是不是太自卑太沒安全感了', '覺得自己很爛所以才需要別人認可', '一直告訴自己要獨立一點卻又做不到', '也覺得自己很沒用', '好久以前被學校同學老師霸凌後', '不知道是身形太弱小還是以前的陰影害的', '真的會想回去報復他們然後拜拜', '然而這四年卻彷彿成為我媽的污點似的，她總說我在這四年變了', '我不懂，為什麼她詢問我的字句中，覺得我孤僻，有社交障礙？', '我在畢業前兩個月得了自律神經失調。', '他研究完我的病歷後告訴我：「我認為你太焦慮了', '去處理我的焦慮問題，我安排了學校的諮商。', '我開始在生活中感覺不到情緒。', '但我就是感覺不到真實的情緒，', '有時候照著鏡子都覺得自己看了討厭，', '曾經有朋友說過在一開始相處時我看起來很不真誠，', '不好親近、像是說著場面話、客套著。', '我不喜歡我自己，', '被自己的情緒反撲到甚至失去生存意識。', '察覺到自己的不對勁，', '巨大的背叛、孤立、父母的失和，', '害怕自己沒辦法處理、也沒有任何人可以穩穩的接住我。', '都是別人說：妳很辛苦，你應該很難過很無助吧？', '看見了一個破碎的自己，', '在一層一層自我保護下壞的亂七八糟的自己蹲在那裡，', '現在的我有點處於悲傷憂鬱狀態', '感覺所有人的目光都在看著我', '感覺所有人都在背後議論我', '嘲笑我', '都認為我很沒用', '扯後腿', '而我又不敢表達我自己', '我不敢放得開', '我覺得我什麼事情都做不好', '我其實小學時曾經被霸凌過', '只因為我是個微胖女', '我很不快樂', '我討厭我自己', '討厭我會害怕跟男生相處', '討厭在團體中只能當被動者', '回到公司之後，開始各種找人講我壞話', '我現在在公司', '根本成了眾矢之的…', '甚至每天都有人當著我的面碎念我，嘲笑我，行為針對我…', '對於自己的個性加上', '無法承受被公司眾多人的行為上霸凌傷害…', '跟同事鬧翻+被同事背叛…整個公司的人討厭我', '現在，我連一年都不想撐了，體會到真正的傷心絕望', '但是每天反覆的想', '我快得病了⋯⋯', '，我就會很玻璃心', '，在想為什麼你要這樣對我', '，我跟你有仇嗎', '，擔心是不是任何人都在講我的壞話', '！', '我覺得我跟身邊的人', '不管是誰', '我都處不來', '常常覺得活著怎麼這麼累', '陷入極度焦慮的時候', '我只想要自己勇敢一點，每當看到身邊的人想做就做、想說就說', '而我卻無法隨心所欲...導致最後什麼也沒做沒說。', '很想解開心裡的結，但卻找不到一個人可以聽我說，我也怕說了被笑', '更怕別人覺得我丟臉，所以我從來沒讓任何人進來我的心裡', '「排擠」真的會導致一個人一輩子的陰影', '也開始嘗試利用運動去認識新的人事物，但心結還是沒開', '我只是短暫的逃避不願意提起以前的事而已。', '現在每天都沒目標的活著，也不知道為什麼要浪費時間', '也不太敢表達自己的想法', '把所有的錯都歸 ...

# %%
level_3_df = origin_df[origin_df['Crisis_Level'] == 3]
level_2_df = origin_df[origin_df['Crisis_Level'] == 2]
level_3_len = len(level_3_df)
level_2_len = len(level_2_df)
print(level_3_len)
print(level_2_len)
# Out:
# 133
# 287

# %%
# duplicate level_3_df from len = level_3_len to len = 100
augment_amount_of_level_2 = 150
level_3_df = pd.concat([level_3_df]*int(sentence_len/level_3_len), ignore_index=True)
# select the first 84+178 sentence
level_3_df = level_3_df.iloc[:sentence_len-augment_amount_of_level_2]
print(len(level_3_df))
# Out:
# 250

# %%
level_2_df = pd.concat([level_2_df]*int(sentence_len/level_3_len), ignore_index=True)
# select the first 84+178 sentence
level_2_df = level_2_df.iloc[:augment_amount_of_level_2]
print(len(level_2_df))
# Out:
# 150

# %%
# randomly choose a sentence from all_negative_sentence and replace with a sentence in level_3_df
import random
seed = 1
random.seed(seed)

for idx, row in level_3_df.iterrows():
    para = row['自殺與憂鬱'].split(' ')
    random_idx_1 = np.random.randint(0, len(para))  
    random_idx_2 = np.random.randint(0, len(all_negative_sentence))    
    para[random_idx_1] = all_negative_sentence[random_idx_2]
    all_negative_sentence.pop(random_idx_2)
    row['自殺與憂鬱'] = ' '.join(para)
    level_3_df.iloc[idx] = row
print(len(all_negative_sentence))
print(len(level_3_df))
# Out:
# 150
# 250

# %%
for idx, row in level_2_df.iterrows():
    para = row['自殺與憂鬱'].split(' ')
    random_idx_1 = np.random.randint(0, len(para))  
    random_idx_2 = np.random.randint(0, len(all_negative_sentence))    
    para[random_idx_1] = all_negative_sentence[random_idx_2]
    all_negative_sentence.pop(random_idx_2)
    row['自殺與憂鬱'] = ' '.join(para)
    level_2_df.iloc[idx] = row
print(len(all_negative_sentence))
print(len(level_2_df))
# Out:
# 0
# 150

# %%
# for idx, row in origin_df.iterrows():
# augment_df_list.append(origin_df)
# print(len(augment_df_list))
augmented_df = pd.concat([origin_df, level_3_df, level_2_df],axis=0, ignore_index=True)
print(augmented_df.columns)
statssss = [0]*4
for index, row in augmented_df.iterrows():
    statssss[row['Crisis_Level']] += 1
print(statssss)
# Out:
# Index(['無標註', '自殺與憂鬱', '自殺行為', '其他類型', 'label', 'Crisis_Level', 'TextID'], dtype='object')
# [1229, 623, 437, 383]

# %%
# balance augmented_df by crisis level, constrain the amount of each level under 600 
maxima = 500
augmented_df_v2 = augmented_df.groupby('Crisis_Level').head(maxima).reset_index(drop=True)
# random shuffle augmented_df_v2
# augmented_df_v2 = augmented_df_v2.sample(frac=1).reset_index(drop=True)
print(augmented_df_v2['Crisis_Level'].value_counts())
# Out:
# 0    500
# 1    500
# 2    437
# 3    383
# Name: Crisis_Level, dtype: int64

# %%
# shuffle the augmented_df without index and set the random_state
augmented_df_v2 = augmented_df_v2.sample(frac=1, random_state=seed).reset_index(drop=True)
# augmented_df.to_excel('data/article/train_augmented_1_v4.xlsx')
augmented_df_v2.to_excel('data/article/train_augmented_1113_SSL_v2.xlsx')
